# %%
# !pip install scikit-learn

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from google.colab import drive
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.decomposition import PCA

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

print(os.listdir('/content/drive/MyDrive/Citadel Data Open 2021/data/'))
# Out:
# ['US_States', 'Global', '.ipynb_checkpoints', 'EU']

# %%
dir = '/content/drive/MyDrive/Citadel Data Open 2021/data/'
trackrecovery_dir = dir + 'US_States/TrackTheRecovery/'
print(os.listdir(trackrecovery_dir))
tr_data = [pd.read_csv(trackrecovery_dir + f) for f in os.listdir(trackrecovery_dir)]
print([tr_data[i] for i in range(len(tr_data))])
# Out:
# ['COVID - State - Daily.csv', 'Affinity - State - Daily.csv', 'Google Mobility - State - Daily.csv', 'Burning Glass - State - Weekly.csv', 'GeoIDs - State.csv', 'Womply - State - Daily.csv', 'Zearn - State - Weekly.csv', 'Employment Combined - State - Daily.csv']
# [       year  month  day  ...  new_case_count new_death_count new_test_count
# 0      2020      1   13  ...               .               .              .
# 1      2020      1   14  ...               .               .              .
# 2      2020      1   15  ...               .               .              .
# 3      2020      1   16  ...               .               .              .
# 4      2020      1   17  ...               .               .              .
# ...     ...    ...  ...  ...             ...             ...            ...
# 20505  2021      2   25  ...            1869             125          21519
# 20506  2021      2   25  ...             808              21          24253
# 20507  2021      2   25  ...             293               8           8197
# 20508  2021      2   25  ...             740              25          32288
# 20509  2021      2   25  ...              96               1           2308
#
# [20510 rows x 16 columns],        year  month  ...  spend_retail_no_grocery  provisional
# 0      2020      1  ...                        .            0
# 1      2020      1  ...                        .            0
# 2      2020      1  ...                        .            0
# 3      2020      1  ...                        .            0
# 4      2020      1  ...                        .            0
# ...     ...    ...  ...                      ...          ...
# 20304  2021      2  ...                     .124            1
# 20305  2021      2  ...                     .202            1
# 20306  2021      2  ...                     .227            1
# 20307  2021      2  ...                     .259            1
# 20308  2021      2  ...                    .0334            1
#
# [20309 rows x 18 columns],        year  month  day  ...  gps_workplaces  gps_residential  gps_away_from_home
# 0      2020      2   24  ...         0.01290          0.00857           -0.007980
# 1      2020      2   24  ...         0.01570          0.00286           -0.000578
# 2      2020      2   24  ...         0.00286          0.00429           -0.007510
# 3      2020      2   24  ...         0.01570          0.00143           -0.003010
# 4      2020      2   24  ...         0.01140          0.00143           -0.002500
# ...     ...    ...  ...  ...             ...              ...                 ...
# 18661  2021      2   23  ...        -0.31900          0.13900           -0.160000
# 18662  2021      2   23  ...        -0.31900          0.11100           -0.132000
# 18663  2021      2   23  ...        -0.23700          0.09140           -0.107000
# 18664  2021      2   23  ...        -0.19000          0.08290           -0.096700
# 18665  2021      2   23  ...        -0.13900          0.05290           -0.065000
#
# [18666 rows x 11 columns],       year  month  day_endofweek  ...  bg_posts_jzgrp345  bg_posts_jz4  bg_posts_jz5
# 0     2021      1              8  ...          -0.168000       -0.2410        -0.355
# 1     2020      3              6  ...          -0.000848        0.1090        -0.123
# 2     2020      5              1  ...          -0.304000       -0.3930        -0.326
# 3     2020      8             21  ...           0.023100       -0.0106        -0.142
# 4     2020      7             17  ...          -0.073500       -0.2360        -0.117
# ...    ...    ...            ...  ...                ...           ...           ...
# 3004  2020      4              3  ...          -0.148000       -0.1600        -0.192
# 3005  2020     12             18  ...          -0.170000       -0.1450        -0.415
# 3006  2021      2             12  ...          -0.187000        0.1200        -0.485
# 3007  2020      7             24  ...          -0.438000       -0.3350        -0.663
# 3008  2021      2             19  ...          -0.346000       -0.1400        -0.555
#
# [3009 rows x 17 columns],     statefips             statename stateabbrev  state_pop2019
# 0           1               Alabama          AL        4903185
# 1           2                Alaska          AK         731545
# 2           4               Arizona          AZ        7278717
# 3           5              Arkansas          AR        3017804
# 4           6            California          CA       39512223
# 5           8              Colorado          CO        5758736
# 6           9           Connecticut          CT        3565287
# 7          10              Delaware          DE         973764
# 8          11  District of Columbia          DC         705749
# 9          12               Florida          FL       21477737
# 10         13               Georgia          GA       10617423
# 11         15                Hawaii          HI        1415872
# 12         16                 Idaho          ID        1787065
# 13         17              Illinois          IL       12671821
# 14         18               Indiana          IN        6732219
# 15         19                  Iowa          IA        3155070
# 16         20                Kansas          KS        2913314
# 17         21              Kentucky          KY        4467673
# 18         22             Louisiana          LA        4648794
# 19         23                 Maine          ME        1344212
# 20         24              Maryland          MD        6045680
# 21         25         Massachusetts          MA        6892503
# 22         26              Michigan          MI        9986857
# 23         27             Minnesota          MN        5639632
# 24         28           Mississippi          MS        2976149
# 25         29              Missouri          MO        6137428
# 26         30               Montana          MT        1068778
# 27         31              Nebraska          NE        1934408
# 28         32                Nevada          NV        3080156
# 29         33         New Hampshire          NH        1359711
# 30         34            New Jersey          NJ        8882190
# 31         35            New Mexico          NM        2096829
# 32         36              New York          NY       19453561
# 33         37        North Carolina          NC       10488084
# 34         38          North Dakota          ND         762062
# 35         39                  Ohio          OH       11689100
# 36         40              Oklahoma          OK        3956971
# 37         41                Oregon          OR        4217737
# 38         42          Pennsylvania          PA       12801989
# 39         44          Rhode Island          RI        1059361
# 40         45        South Carolina          SC        5148714
# 41         46          South Dakota          SD         884659
# 42         47             Tennessee          TN        6829174
# 43         48                 Texas          TX       28995881
# 44         49                  Utah          UT        3205958
# 45         50               Vermont          VT         623989
# 46         51              Virginia          VA        8535519
# 47         53            Washington          WA        7614893
# 48         54         West Virginia          WV        1792147
# 49         55             Wisconsin          WI        5822434
# 50         56               Wyoming          WY         578759,        year  month  day  ...  revenue_ss60  revenue_ss65  revenue_ss70
# 0      2020      1   10  ...         .0139        -.0145      0.012300
# 1      2020      1   10  ...        -.0463         -.129      0.024200
# 2      2020      1   10  ...         -.017        -.0205     -0.000071
# 3      2020      1   10  ...        -.0616         -.035     -0.047300
# 4      2020      1   10  ...        .00403       -.00156     -0.013500
# ...     ...    ...  ...  ...           ...           ...           ...
# 20143  2021      2   10  ...        -.0426         -.423     -0.637000
# 20144  2021      2   10  ...         -.126         -.343     -0.641000
# 20145  2021      2   10  ...        -.0347         -.148     -0.412000
# 20146  2021      2   10  ...          .302          -.37     -0.533000
# 20147  2021      2   10  ...         -.113         -.174     -0.560000
#
# [20148 rows x 20 columns],       statefips  year  ...  break_engagement_incmiddle  break_badges_incmiddle
# 0             1  2019  ...                           .                       .
# 1             1  2019  ...                           .                       .
# 2             1  2019  ...                           .                       .
# 3             1  2019  ...                           .                       .
# 4             1  2019  ...                           .                       .
# ...         ...   ...  ...                         ...                     ...
# 5605         56  2021  ...                           .                       .
# 5606         56  2021  ...                           .                       .
# 5607         56  2021  ...                           .                       .
# 5608         56  2021  ...                           .                       .
# 5609         56  2021  ...                           .                       .
#
# [5610 rows x 20 columns],        year  month  day  ...  emp_combined_ss60 emp_combined_ss65 emp_combined_ss70
# 0      2020      1   14  ...             .00358           .000385           -.00343
# 1      2020      1   14  ...                  .                 .                 .
# 2      2020      1   14  ...             .00431           -.00143             .0181
# 3      2020      1   14  ...            -.00587                 .            -.0181
# 4      2020      1   14  ...             .00166            .00343            .00195
# ...     ...    ...  ...  ...                ...               ...               ...
# 17029  2020     12   12  ...            -.00681             -.106             -.276
# 17030  2020     12   12  ...             -.0497            -.0503             -.202
# 17031  2020     12   12  ...              -.317             -.222              .134
# 17032  2020     12   12  ...             -.0284            -.0327             -.288
# 17033  2020     12   12  ...             -.0228              .168            .00681
#
# [17034 rows x 12 columns]]

# %%
for sub_dat in tr_data:
  if 'day_endofweek' in sub_dat.columns:
    sub_dat.loc[:,'day'] = sub_dat['day_endofweek']
  if 'year' in sub_dat.columns:
    sub_dat.loc[:,'Date'] = pd.to_datetime(sub_dat['year'].astype(str) + '/' + sub_dat['month'].astype('str') + '/' + sub_dat['day'].astype(str))

master_dat = tr_data[0]
for i in range(1,len(tr_data)):
  if 'Date' in tr_data[i].columns:
    master_dat = master_dat.merge(right=tr_data[i], on=['statefips', 'Date', 'year', 'month', 'day'], how='outer')

geo_xwalk = pd.read_csv(trackrecovery_dir + 'GeoIDs - State.csv')
geo_xwalk = geo_xwalk[['statefips', 'statename', 'stateabbrev']]
master_dat = master_dat.merge(geo_xwalk, how='left', indicator='xwalk')
print(master_dat['xwalk'].value_counts())
print(master_dat.columns)
print(master_dat['statefips'].value_counts().sort_index())
# Out:
# both          24115
# right_only        0
# left_only         0
# Name: xwalk, dtype: int64
# Index(['year', 'month', 'day', 'statefips', 'case_count', 'death_count',
#        'test_count', 'case_rate', 'death_rate', 'test_rate', 'new_case_rate',
#        'new_death_rate', 'new_test_rate', 'new_case_count', 'new_death_count',
#        'new_test_count', 'Date', 'freq', 'spend_acf', 'spend_aer', 'spend_all',
#        'spend_apg', 'spend_grf', 'spend_hcs', 'spend_tws', 'spend_all_inchigh',
#        'spend_all_inclow', 'spend_all_incmiddle', 'spend_retail_w_grocery',
#        'spend_retail_no_grocery', 'provisional', 'gps_retail_and_recreation',
#        'gps_grocery_and_pharmacy', 'gps_parks', 'gps_transit_stations',
#        'gps_workplaces', 'gps_residential', 'gps_away_from_home',
#        'day_endofweek_x', 'bg_posts', 'bg_posts_ss30', 'bg_posts_ss55',
#        'bg_posts_ss60', 'bg_posts_ss65', 'bg_posts_ss70', 'bg_posts_jz1',
#        'bg_posts_jzgrp12', 'bg_posts_jz2', 'bg_posts_jz3', 'bg_posts_jzgrp345',
#        'bg_posts_jz4', 'bg_posts_jz5', 'merchants_all', 'merchants_inchigh',
#        'merchants_inclow', 'merchants_incmiddle', 'merchants_ss40',
#        'merchants_ss60', 'merchants_ss65', 'merchants_ss70', 'revenue_all',
#        'revenue_inchigh', 'revenue_inclow', 'revenue_incmiddle',
#        'revenue_ss40', 'revenue_ss60', 'revenue_ss65', 'revenue_ss70',
#        'day_endofweek_y', 'engagement', 'badges', 'engagement_inchigh',
#        'badges_inchigh', 'engagement_inclow', 'badges_inclow',
#        'engagement_incmiddle', 'badges_incmiddle', 'break_engagement',
#        'break_badges', 'break_engagement_inchigh', 'break_badges_inchigh',
#        'break_engagement_inclow', 'break_badges_inclow',
#        'break_engagement_incmiddle', 'break_badges_incmiddle', 'emp_combined',
#        'emp_combined_inclow', 'emp_combined_incmiddle', 'emp_combined_inchigh',
#        'emp_combined_ss40', 'emp_combined_ss60', 'emp_combined_ss65',
#        'emp_combined_ss70', 'statename', 'stateabbrev', 'xwalk'],
#       dtype='object')
# 1     473
# 2     473
# 4     473
# 5     473
# 6     473
# 8     473
# 9     473
# 10    473
# 11    465
# 12    473
# 13    473
# 15    473
# 16    473
# 17    473
# 18    473
# 19    473
# 20    473
# 21    473
# 22    473
# 23    473
# 24    473
# 25    473
# 26    473
# 27    473
# 28    473
# 29    473
# 30    473
# 31    473
# 32    473
# 33    473
# 34    473
# 35    473
# 36    473
# 37    473
# 38    473
# 39    473
# 40    473
# 41    473
# 42    473
# 44    473
# 45    473
# 46    473
# 47    473
# 48    473
# 49    473
# 50    473
# 51    473
# 53    473
# 54    473
# 55    473
# 56    473
# Name: statefips, dtype: int64

# %%
master_dat['Date'].describe()
fields_to_plot = ['spend_acf', 'spend_aer', 'spend_all', 
                  'spend_apg', 'spend_grf', 'spend_hcs', 'spend_tws', 'spend_all_inchigh', 
                  'spend_all_inclow', 'spend_all_incmiddle', 'spend_retail_w_grocery',
                  'spend_retail_no_grocery', 'gps_retail_and_recreation',
                  'gps_grocery_and_pharmacy', 'gps_parks', 'gps_transit_stations',
                  'gps_workplaces', 'gps_residential', 'gps_away_from_home', 'merchants_all', 'merchants_inchigh',
                  'merchants_inclow', 'merchants_incmiddle', 'merchants_ss40',
                  'merchants_ss60', 'merchants_ss65', 'merchants_ss70', 'revenue_all',
                  'revenue_inchigh', 'revenue_inclow', 'revenue_incmiddle',
                  'revenue_ss40', 'revenue_ss60', 'revenue_ss65', 'revenue_ss70', 'emp_combined',
                  'emp_combined_inclow', 'emp_combined_incmiddle', 'emp_combined_inchigh',
                  'emp_combined_ss40', 'emp_combined_ss60', 'emp_combined_ss65',
                  'emp_combined_ss70']
master_dat.loc[:,fields_to_plot] = master_dat.loc[:,fields_to_plot].replace('.', np.nan)
master_dat.loc[:,fields_to_plot] = master_dat.loc[:,fields_to_plot].astype(float)

master_dat.to_csv(dir + 'US_States/cleaned_data/track_recovery_clean.csv')

plt.figure(figsize=(8,8))
plt.plot(master_dat.loc[master_dat['statefips']==6,'Date'], master_dat.loc[master_dat['statefips']==6, fields_to_plot])
plt.title('California')
#plt.legend(fields_to_plot)

plt.figure(figsize=(8,8))
plt.plot(master_dat.loc[master_dat['statefips']==12,'Date'], master_dat.loc[master_dat['statefips']==12, fields_to_plot])
plt.title('Florida')

plt.figure(figsize=(8,8))
plt.plot(master_dat.loc[master_dat['statefips']==46,'Date'], master_dat.loc[master_dat['statefips']==46, fields_to_plot])
plt.title('South Dakota')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.

# %%
open_table = pd.read_csv(dir + 'US_States/YoY_Seated_Diner_Data.csv')
ot_us = open_table.loc[open_table['Type']=='state']

geo_xwalk = pd.read_csv(trackrecovery_dir + 'GeoIDs - State.csv')
geo_xwalk = geo_xwalk[['statefips', 'statename', 'stateabbrev']]
ot_us = ot_us.merge(geo_xwalk, left_on='Name', right_on='statename', how='left', indicator='match')
ot_us = ot_us.loc[ot_us['match'] == 'both']
ot_us = ot_us.set_index(['Type', 'Name', 'statename', 'stateabbrev', 'statefips', 'match'])
col_orig = list(ot_us.columns)
col_orig = [s.replace('.1', '') for s in col_orig]
columns_corrected = [col_orig[i]+'/20' if i <= col_orig.index('12/31') else col_orig[i]+'/21' for i in range(len(col_orig))]
ot_us.columns = columns_corrected

ot_us = pd.melt(ot_us, var_name='date_str', ignore_index=False).reset_index()
ot_us['Date'] = pd.to_datetime(ot_us['date_str'])
ot_us['open_table_seatings'] = ot_us['value'] / 100
print(ot_us['statename'].value_counts().sort_index())
ot_us = ot_us[['statefips', 'Date', 'open_table_seatings']]

ot_us.to_csv(dir + 'US_States/cleaned_data/open_table_clean.csv')
# Out:
# Alabama                 377
# Arizona                 377
# California              377
# Colorado                377
# Connecticut             377
# Delaware                377
# District of Columbia    377
# Florida                 377
# Georgia                 377
# Hawaii                  377
# Illinois                377
# Indiana                 377
# Kansas                  377
# Kentucky                377
# Louisiana               377
# Maine                   377
# Maryland                377
# Massachusetts           377
# Michigan                377
# Minnesota               377
# Missouri                377
# Nebraska                377
# Nevada                  377
# New Hampshire           377
# New Jersey              377
# New Mexico              377
# New York                377
# North Carolina          377
# Ohio                    377
# Oklahoma                377
# Oregon                  377
# Pennsylvania            377
# Rhode Island            377
# South Carolina          377
# Tennessee               377
# Texas                   377
# Utah                    377
# Virginia                377
# Washington              377
# Wisconsin               377
# Name: statename, dtype: int64

# %%
### READY FOR FINAL PLOT @SHERIDAN

master_dat_ot = master_dat.merge(ot_us, on=['statefips', 'Date'], how='left')
print(master_dat_ot['open_table_seatings'].describe())

fields_to_plot = ['open_table_seatings', 'spend_acf', 'spend_aer', 'spend_all', 
                  'spend_apg', 'spend_grf', 'spend_hcs', 'spend_tws', 'spend_all_inchigh', 
                  'spend_all_inclow', 'spend_all_incmiddle', 'spend_retail_w_grocery',
                  'spend_retail_no_grocery', 'gps_retail_and_recreation',
                  'gps_grocery_and_pharmacy', 'gps_transit_stations',
                  'gps_workplaces', 'gps_residential', 'gps_away_from_home', 'merchants_all', 'merchants_inchigh',
                  'merchants_inclow', 'merchants_incmiddle', 'merchants_ss40',
                  'merchants_ss60', 'merchants_ss65', 'merchants_ss70', 'revenue_all',
                  'revenue_inchigh', 'revenue_inclow', 'revenue_incmiddle',
                  'revenue_ss40', 'revenue_ss60', 'revenue_ss65', 'revenue_ss70', 'emp_combined',
                  'emp_combined_inclow', 'emp_combined_incmiddle', 'emp_combined_inchigh',
                  'emp_combined_ss40', 'emp_combined_ss60', 'emp_combined_ss65',
                  'emp_combined_ss70']
master_dat_ot.loc[:,fields_to_plot] = master_dat_ot.loc[:,fields_to_plot].replace('.', np.nan)
master_dat_ot.loc[:,fields_to_plot] = master_dat_ot.loc[:,fields_to_plot].astype(float)

plt.figure(figsize=(8,8))
plt.plot(master_dat_ot.loc[master_dat_ot['statefips']==6,'Date'], master_dat_ot.loc[master_dat_ot['statefips']==6, fields_to_plot])
plt.title('California')
#plt.legend(fields_to_plot)

plt.figure(figsize=(8,8))
plt.plot(master_dat_ot.loc[master_dat_ot['statefips']==12,'Date'], master_dat_ot.loc[master_dat_ot['statefips']==12, fields_to_plot])
plt.title('Florida')

plt.figure(figsize=(8,8))
plt.plot(master_dat_ot.loc[master_dat_ot['statefips']==45,'Date'], master_dat_ot.loc[master_dat_ot['statefips']==45, fields_to_plot])
plt.title('South Carolina')

# plt.figure(figsize=(8,8))
# plt.plot(master_dat_ot.loc[master_dat_ot['statefips']==46,'Date'], master_dat_ot.loc[master_dat_ot['statefips']==46, fields_to_plot])
# plt.title('South Dakota')
# for f in fields_to_plot:
#   print(f, (master_dat_ot.loc[master_dat_ot['statefips']==46, f] > 3).sum())
# plt.show()
# Out:
# count    14165.000000
# mean        -0.562714
# std          0.315501
# min         -1.000000
# 25%         -0.815400
# 50%         -0.550000
# 75%         -0.372000
# max          3.787800
# Name: open_table_seatings, dtype: float64
# Text(0.5, 1.0, 'South Carolina')

# %%
bls_dat = pd.read_csv(dir + 'US_States/Trips_by_Distance.csv')
bls_dat = bls_dat.loc[bls_dat['Level'] == 'State']
bls_dat.loc[:,'statefips'] = bls_dat['State FIPS']
bls_dat['Date'] = pd.to_datetime(bls_dat['Date'])
bls_dat = bls_dat.sort_values(by=['statefips', 'Date']).reset_index()
print(bls_dat.columns)
# Out:
# Index(['index', 'Level', 'Date', 'State FIPS', 'State Postal Code',
#        'County FIPS', 'County Name', 'Population Staying at Home',
#        'Population Not Staying at Home', 'Number of Trips',
#        'Number of Trips <1', 'Number of Trips 1-3', 'Number of Trips 3-5',
#        'Number of Trips 5-10', 'Number of Trips 10-25',
#        'Number of Trips 25-50', 'Number of Trips 50-100',
#        'Number of Trips 100-250', 'Number of Trips 250-500',
#        'Number of Trips >=500', 'Row ID', 'statefips'],
#       dtype='object')

# %%
mobility_vars = ['Population Staying at Home', 
                 'Population Not Staying at Home', 'Number of Trips',
                 'Number of Trips <1', 'Number of Trips 1-3', 'Number of Trips 3-5',
                 'Number of Trips 5-10', 'Number of Trips 10-25',
                 'Number of Trips 25-50', 'Number of Trips 50-100',
                 'Number of Trips 100-250', 'Number of Trips 250-500',
                 'Number of Trips >=500']

def rolling_forward_mean(dat, var_name, groupby, periods):
  ser = dat[[groupby, var_name]].copy()
  cols = []
  for i in range(periods):
    ser[var_name + '_lag_' + str(i)] = ser.groupby(groupby)[var_name].shift(-i)
    cols = cols + [var_name + '_lag_' + str(i)]
  return ser[cols].mean(axis=1)

for m in mobility_vars:
  bls_dat[m+'_weekroll'] = rolling_forward_mean(bls_dat, m, 'statefips', 7)
  bls_dat[m+'_weekrollfirst'] = bls_dat.groupby('statefips')[m+'_weekroll'].transform('first')
  bls_dat[m+'_weekrollnorm'] = bls_dat[m+'_weekroll'] / bls_dat[m+'_weekrollfirst'] - 1

state_subset = [6, 12, 29, 36, 46]
plt.figure(figsize=(15,8))
bls_dat.loc[bls_dat['statefips'].isin(state_subset)].groupby(['Date', 'statefips'])['Population Not Staying at Home_weekrollnorm'].mean().unstack().plot(ax=plt.gca())

plt.figure(figsize=(15,8))
bls_dat.loc[bls_dat['statefips'].isin(state_subset)].groupby(['Date', 'statefips'])['Number of Trips_weekrollnorm'].mean().unstack().plot(ax=plt.gca())

plt.figure(figsize=(15,8))
bls_dat.loc[bls_dat['statefips'].isin(state_subset)].groupby(['Date', 'statefips'])['Population Staying at Home_weekrollnorm'].mean().unstack().plot(ax=plt.gca())

# %%
# Merging BTS data into master
# master_dat = master_dat.merge(bls_dat_trim, on=['statefips', 'Date'], how='left')
# fields_to_plot = ['open_table_seatings', 'spend_acf', 'spend_aer', 'spend_all', 
#                   'spend_apg', 'spend_grf', 'spend_hcs', 'spend_tws', 'spend_all_inchigh', 
#                   'spend_all_inclow', 'spend_all_incmiddle', 'spend_retail_w_grocery',
#                   'spend_retail_no_grocery', 'gps_retail_and_recreation',
#                   'gps_grocery_and_pharmacy', 'gps_parks', 'gps_transit_stations',
#                   'gps_workplaces', 'gps_residential', 'gps_away_from_home', 'merchants_all', 'merchants_inchigh',
#                   'merchants_inclow', 'merchants_incmiddle', 'merchants_ss40',
#                   'merchants_ss60', 'merchants_ss65', 'merchants_ss70', 'revenue_all',
#                   'revenue_inchigh', 'revenue_inclow', 'revenue_incmiddle',
#                   'revenue_ss40', 'revenue_ss60', 'revenue_ss65', 'revenue_ss70', 'emp_combined',
#                   'emp_combined_inclow', 'emp_combined_incmiddle', 'emp_combined_inchigh',
#                   'emp_combined_ss40', 'emp_combined_ss60', 'emp_combined_ss65',
#                   'emp_combined_ss70']
# bts_dat_fields = [m + '_weekrollnorm' for m in mobility_vars]
# fields_to_plot_full = fields_to_plot + bts_dat_fields
# master_dat.loc[:,fields_to_plot_full] = master_dat.loc[:,fields_to_plot_full].replace('.', np.nan)
# master_dat.loc[:,fields_to_plot_full] = master_dat.loc[:,fields_to_plot_full].astype(float)

# master_dat.to_csv(dir + 'US_States/cleaned_data/master_mobility_clean.csv')

# plt.figure(figsize=(8,8))
# plt.plot(master_dat.loc[master_dat['statefips']==6,'Date'], master_dat.loc[master_dat['statefips']==6, fields_to_plot_full])
# plt.title('California')

# plt.figure(figsize=(8,8))
# plt.plot(master_dat.loc[master_dat['statefips']==12,'Date'], master_dat.loc[master_dat['statefips']==12, fields_to_plot_full])
# plt.title('Florida')
# plt.show()

# %%
# Data cleaning before PCA
pca_fields = ['open_table_seatings', 'spend_acf', 'spend_aer', 'spend_all', 
                  'spend_apg', 'spend_grf', 'spend_hcs', 'spend_tws', 'spend_all_inchigh', 
                  'spend_all_inclow', 'spend_all_incmiddle', 'spend_retail_w_grocery',
                  'spend_retail_no_grocery', 'gps_retail_and_recreation',
                  'gps_grocery_and_pharmacy', 'gps_parks', 'gps_transit_stations',
                  'gps_workplaces', 'gps_residential', 'gps_away_from_home', 'merchants_all', 'merchants_inchigh',
                  'merchants_inclow', 'merchants_incmiddle', 'merchants_ss40',
                  'merchants_ss60', 'merchants_ss65', 'merchants_ss70', 'revenue_all',
                  'revenue_inchigh', 'revenue_inclow', 'revenue_incmiddle',
                  'revenue_ss40', 'revenue_ss60', 'revenue_ss65', 'revenue_ss70', 'emp_combined',
                  'emp_combined_inclow', 'emp_combined_incmiddle', 'emp_combined_inchigh',
                  'emp_combined_ss40', 'emp_combined_ss60', 'emp_combined_ss65',
                  'emp_combined_ss70']
master_dat_trim = master_dat_ot.loc[(master_dat_ot['Date'] >= '2020/02/01') & (master_dat_ot['Date'] <= '2021/03/01')].reset_index()
data_only = master_dat_trim[['statefips', 'statename', 'Date'] + pca_fields]
# Tells us how many data entries are filled for each variable. Note that there are 19941 total rows.
print(data_only.describe().loc['count'])

# Start by filling data using linear interpolation
data_filled = data_only.groupby('statefips').apply(lambda group: group.interpolate(method='index', limit_direction='both'))
print(data_filled.describe().loc['count'])
print(data_filled['statename'].value_counts().sort_index())
print(data_filled.groupby('statename')[pca_fields].agg(lambda x: x.isnull().sum()))

# One version is to exclude any data that is not complete
dat_completeness = data_filled.describe().loc['count']
complete_only = list(dat_completeness.loc[dat_completeness == dat_completeness.max()].index)
# Excluding gps_parks because it seems to drive a lot of variation
exclude = ['statefips', 'statename', 'Date', 'gps_parks']
complete_only = [c for c in complete_only if c not in exclude]
print(complete_only)
# Out:
# statefips                    19941.0
# open_table_seatings          14165.0
# spend_acf                    18755.0
# spend_aer                    18755.0
# spend_all                    18755.0
# spend_apg                    18755.0
# spend_grf                    18755.0
# spend_hcs                    18755.0
# spend_tws                    18755.0
# spend_all_inchigh            18755.0
# spend_all_inclow             18007.0
# spend_all_incmiddle          18755.0
# spend_retail_w_grocery       18755.0
# spend_retail_no_grocery      18755.0
# gps_retail_and_recreation    18666.0
# gps_grocery_and_pharmacy     18666.0
# gps_parks                    18226.0
# gps_transit_stations         18513.0
# gps_workplaces               18666.0
# gps_residential              18666.0
# gps_away_from_home           18666.0
# merchants_all                19026.0
# merchants_inchigh            19026.0
# merchants_inclow             19026.0
# merchants_incmiddle          19026.0
# merchants_ss40               19026.0
# merchants_ss60               18680.0
# merchants_ss65               19022.0
# merchants_ss70               19026.0
# revenue_all                  19026.0
# revenue_inchigh              19026.0
# revenue_inclow               19026.0
# revenue_incmiddle            19026.0
# revenue_ss40                 19026.0
# revenue_ss60                 18680.0
# revenue_ss65                 19022.0
# revenue_ss70                 19026.0
# emp_combined                 15168.0
# emp_combined_inclow          15168.0
# emp_combined_incmiddle       15168.0
# emp_combined_inchigh         13904.0
# emp_combined_ss40            14852.0
# emp_combined_ss60            15168.0
# emp_combined_ss65            14536.0
# emp_combined_ss70            14852.0
# Name: count, dtype: float64
# statefips                    19941.0
# open_table_seatings          15640.0
# spend_acf                    19941.0
# spend_aer                    19941.0
# spend_all                    19941.0
# spend_apg                    19941.0
# spend_grf                    19941.0
# spend_hcs                    19941.0
# spend_tws                    19941.0
# spend_all_inchigh            19941.0
# spend_all_inclow             19159.0
# spend_all_incmiddle          19941.0
# spend_retail_w_grocery       19941.0
# spend_retail_no_grocery      19941.0
# gps_retail_and_recreation    19941.0
# gps_grocery_and_pharmacy     19941.0
# gps_parks                    19941.0
# gps_transit_stations         19941.0
# gps_workplaces               19941.0
# gps_residential              19941.0
# gps_away_from_home           19941.0
# merchants_all                19941.0
# merchants_inchigh            19941.0
# merchants_inclow             19941.0
# merchants_incmiddle          19941.0
# merchants_ss40               19941.0
# merchants_ss60               19550.0
# merchants_ss65               19941.0
# merchants_ss70               19941.0
# revenue_all                  19941.0
# revenue_inchigh              19941.0
# revenue_inclow               19941.0
# revenue_incmiddle            19941.0
# revenue_ss40                 19941.0
# revenue_ss60                 19550.0
# revenue_ss65                 19941.0
# revenue_ss70                 19941.0
# emp_combined                 18768.0
# emp_combined_inclow          18768.0
# emp_combined_incmiddle       18768.0
# emp_combined_inchigh         17204.0
# emp_combined_ss40            18377.0
# emp_combined_ss60            18768.0
# emp_combined_ss65            17986.0
# emp_combined_ss70            18377.0
# Name: count, dtype: float64
# Alabama                 391
# Alaska                  391
# Arizona                 391
# Arkansas                391
# California              391
# Colorado                391
# Connecticut             391
# Delaware                391
# District of Columbia    391
# Florida                 391
# Georgia                 391
# Hawaii                  391
# Idaho                   391
# Illinois                391
# Indiana                 391
# Iowa                    391
# Kansas                  391
# Kentucky                391
# Louisiana               391
# Maine                   391
# Maryland                391
# Massachusetts           391
# Michigan                391
# Minnesota               391
# Mississippi             391
# Missouri                391
# Montana                 391
# Nebraska                391
# Nevada                  391
# New Hampshire           391
# New Jersey              391
# New Mexico              391
# New York                391
# North Carolina          391
# North Dakota            391
# Ohio                    391
# Oklahoma                391
# Oregon                  391
# Pennsylvania            391
# Rhode Island            391
# South Carolina          391
# South Dakota            391
# Tennessee               391
# Texas                   391
# Utah                    391
# Vermont                 391
# Virginia                391
# Washington              391
# West Virginia           391
# Wisconsin               391
# Wyoming                 391
# Name: statename, dtype: int64
#                       open_table_seatings  ...  emp_combined_ss70
# statename                                  ...
# Alabama                               0.0  ...                0.0
# Alaska                              391.0  ...              391.0
# Arizona                               0.0  ...                0.0
# Arkansas                            391.0  ...                0.0
# California                            0.0  ...                0.0
# Colorado                              0.0  ...                0.0
# Connecticut                           0.0  ...                0.0
# Delaware                              0.0  ...                0.0
# District of Columbia                  0.0  ...                0.0
# Florida                               0.0  ...                0.0
# Georgia                               0.0  ...                0.0
# Hawaii                                0.0  ...                0.0
# Idaho                               391.0  ...                0.0
# Illinois                              0.0  ...                0.0
# Indiana                               0.0  ...                0.0
# Iowa                                391.0  ...                0.0
# Kansas                                0.0  ...                0.0
# Kentucky                              0.0  ...                0.0
# Louisiana                             0.0  ...                0.0
# Maine                                 0.0  ...                0.0
# Maryland                              0.0  ...                0.0
# Massachusetts                         0.0  ...                0.0
# Michigan                              0.0  ...                0.0
# Minnesota                             0.0  ...                0.0
# Mississippi                         391.0  ...              391.0
# Missouri                              0.0  ...                0.0
# Montana                             391.0  ...                0.0
# Nebraska                              0.0  ...                0.0
# Nevada                                0.0  ...                0.0
# New Hampshire                         0.0  ...                0.0
# New Jersey                            0.0  ...                0.0
# New Mexico                            0.0  ...                0.0
# New York                              0.0  ...                0.0
# North Carolina                        0.0  ...                0.0
# North Dakota                        391.0  ...              391.0
# Ohio                                  0.0  ...                0.0
# Oklahoma                              0.0  ...                0.0
# Oregon                                0.0  ...              391.0
# Pennsylvania                          0.0  ...                0.0
# Rhode Island                          0.0  ...                0.0
# South Carolina                        0.0  ...                0.0
# South Dakota                        391.0  ...                0.0
# Tennessee                             0.0  ...                0.0
# Texas                                 0.0  ...                0.0
# Utah                                  0.0  ...                0.0
# Vermont                             391.0  ...                0.0
# Virginia                              0.0  ...                0.0
# Washington                            0.0  ...                0.0
# West Virginia                       391.0  ...                0.0
# Wisconsin                             0.0  ...                0.0
# Wyoming                             391.0  ...                0.0
#
# [51 rows x 44 columns]
# ['spend_acf', 'spend_aer', 'spend_all', 'spend_apg', 'spend_grf', 'spend_hcs', 'spend_tws', 'spend_all_inchigh', 'spend_all_incmiddle', 'spend_retail_w_grocery', 'spend_retail_no_grocery', 'gps_retail_and_recreation', 'gps_grocery_and_pharmacy', 'gps_transit_stations', 'gps_workplaces', 'gps_residential', 'gps_away_from_home', 'merchants_all', 'merchants_inchigh', 'merchants_inclow', 'merchants_incmiddle', 'merchants_ss40', 'merchants_ss65', 'merchants_ss70', 'revenue_all', 'revenue_inchigh', 'revenue_inclow', 'revenue_incmiddle', 'revenue_ss40', 'revenue_ss65', 'revenue_ss70']

# %%
### READY FOR FINAL PLOT @SHERIDAN

pca = PCA()
res = pca.fit(data_filled[complete_only])
print(res.explained_variance_ratio_)
plt.plot(range(len(res.explained_variance_ratio_) + 1), np.insert(res.explained_variance_ratio_.cumsum(), 0, 0))
plt.ylim([0,1])
plt.title('Variance explained by Principal Components')

principal_components = res.transform(data_filled[complete_only])
n_components = 5
principal_components_dat = pd.DataFrame(principal_components[:,0:n_components], 
                                        columns=['pca_' + str(i) for i in range(n_components)])
# Out:
# [5.33033482e-01 1.58197333e-01 5.14904573e-02 4.90031185e-02
#  4.17652317e-02 2.63714875e-02 2.58390857e-02 1.91034840e-02
#  1.70694239e-02 1.25474137e-02 1.02224227e-02 9.25267327e-03
#  7.43246135e-03 6.44184461e-03 5.27398794e-03 4.78575098e-03
#  4.17306321e-03 3.54496575e-03 3.03428412e-03 2.64858499e-03
#  2.41798110e-03 1.62989577e-03 1.52381519e-03 1.03573733e-03
#  6.05893668e-04 5.46338808e-04 4.29835793e-04 3.21256686e-04
#  1.78747551e-04 7.60994286e-05 3.84186373e-06]

# %%
print(principal_components_dat)
print(master_dat_trim)
final_dat_pca = pd.concat([master_dat_trim, principal_components_dat], axis=1)
print(final_dat_pca)
# Out:
#           pca_0     pca_1     pca_2     pca_3     pca_4
# 0      1.247116 -0.225363  0.225996 -0.249799 -0.033629
# 1      1.179397 -0.141383 -0.009964 -0.258297 -0.256894
# 2      1.237199 -0.123781  0.175214 -0.314870 -0.112176
# 3      1.262326 -0.025004  0.230765 -0.310650 -0.080958
# 4      1.237363 -0.158110  0.222947 -0.292681 -0.105330
# ...         ...       ...       ...       ...       ...
# 19936 -0.349612  0.296414  0.090564 -0.007886 -0.048547
# 19937  0.302382  0.101464  0.322891  0.625559 -0.131549
# 19938  0.086376  0.321112 -0.122875  0.008588 -0.193201
# 19939 -0.103353  0.308483 -0.119924  0.019471 -0.059418
# 19940  0.027563 -0.076042 -0.092659 -0.115355 -0.034637
#
# [19941 rows x 5 columns]
#        index  year  month  ...  stateabbrev  xwalk open_table_seatings
# 0        569  2020      2  ...           AL   both                 NaN
# 1        570  2020      2  ...           AK   both                 NaN
# 2        571  2020      2  ...           AZ   both                 NaN
# 3        572  2020      2  ...           AR   both                 NaN
# 4        573  2020      2  ...           CA   both                 NaN
# ...      ...   ...    ...  ...          ...    ...                 ...
# 19936  20505  2021      2  ...           VA   both             -0.4380
# 19937  20506  2021      2  ...           WA   both             -0.6041
# 19938  20507  2021      2  ...           WV   both                 NaN
# 19939  20508  2021      2  ...           WI   both             -0.4543
# 19940  20509  2021      2  ...           WY   both                 NaN
#
# [19941 rows x 98 columns]
#        index  year  month  day  ...     pca_1     pca_2     pca_3     pca_4
# 0        569  2020      2    1  ... -0.225363  0.225996 -0.249799 -0.033629
# 1        570  2020      2    1  ... -0.141383 -0.009964 -0.258297 -0.256894
# 2        571  2020      2    1  ... -0.123781  0.175214 -0.314870 -0.112176
# 3        572  2020      2    1  ... -0.025004  0.230765 -0.310650 -0.080958
# 4        573  2020      2    1  ... -0.158110  0.222947 -0.292681 -0.105330
# ...      ...   ...    ...  ...  ...       ...       ...       ...       ...
# 19936  20505  2021      2   25  ...  0.296414  0.090564 -0.007886 -0.048547
# 19937  20506  2021      2   25  ...  0.101464  0.322891  0.625559 -0.131549
# 19938  20507  2021      2   25  ...  0.321112 -0.122875  0.008588 -0.193201
# 19939  20508  2021      2   25  ...  0.308483 -0.119924  0.019471 -0.059418
# 19940  20509  2021      2   25  ... -0.076042 -0.092659 -0.115355 -0.034637
#
# [19941 rows x 103 columns]

# %%
### READY FOR FINAL PLOT @SHERIDAN

print(list(final_dat_pca.columns))
plt.figure(figsize=(15,8))
final_dat_pca.groupby(['Date', 'statename'])['pca_0'].mean().unstack().plot(ax=plt.gca())
plt.figure(figsize=(15,8))
final_dat_pca.groupby(['Date', 'statename'])['pca_1'].mean().unstack().plot(ax=plt.gca())
state_subset = [6, 12, 36, 45, 46]
plt.figure(figsize=(15,8))
final_dat_pca.loc[final_dat_pca['statefips'].isin(state_subset)].groupby(['Date', 'statename'])['pca_0'].mean().unstack().plot(ax=plt.gca())

print(final_dat_pca.corr()['pca_0'][fields_to_plot])
print(final_dat_pca.corr()['pca_1'][fields_to_plot])
plt.figure(figsize=(10,10))
sns.heatmap(final_dat_pca[fields_to_plot].corr(), cmap='coolwarm', mask=np.tril(np.ones((len(fields_to_plot), len(fields_to_plot)))).astype(np.bool), 
            linewidth=1, linecolor='white')
plt.figure(figsize=(10,10))
sns.heatmap(final_dat_pca.corr()[['pca_0','pca_1', 'pca_2', 'pca_3', 'pca_4']].loc[fields_to_plot], cmap='coolwarm')
# Out:
# ['index', 'year', 'month', 'day', 'statefips', 'case_count', 'death_count', 'test_count', 'case_rate', 'death_rate', 'test_rate', 'new_case_rate', 'new_death_rate', 'new_test_rate', 'new_case_count', 'new_death_count', 'new_test_count', 'Date', 'freq', 'spend_acf', 'spend_aer', 'spend_all', 'spend_apg', 'spend_grf', 'spend_hcs', 'spend_tws', 'spend_all_inchigh', 'spend_all_inclow', 'spend_all_incmiddle', 'spend_retail_w_grocery', 'spend_retail_no_grocery', 'provisional', 'gps_retail_and_recreation', 'gps_grocery_and_pharmacy', 'gps_parks', 'gps_transit_stations', 'gps_workplaces', 'gps_residential', 'gps_away_from_home', 'day_endofweek_x', 'bg_posts', 'bg_posts_ss30', 'bg_posts_ss55', 'bg_posts_ss60', 'bg_posts_ss65', 'bg_posts_ss70', 'bg_posts_jz1', 'bg_posts_jzgrp12', 'bg_posts_jz2', 'bg_posts_jz3', 'bg_posts_jzgrp345', 'bg_posts_jz4', 'bg_posts_jz5', 'merchants_all', 'merchants_inchigh', 'merchants_inclow', 'merchants_incmiddle', 'merchants_ss40', 'merchants_ss60', 'merchants_ss65', 'merchants_ss70', 'revenue_all', 'revenue_inchigh', 'revenue_inclow', 'revenue_incmiddle', 'revenue_ss40', 'revenue_ss60', 'revenue_ss65', 'revenue_ss70', 'day_endofweek_y', 'engagement', 'badges', 'engagement_inchigh', 'badges_inchigh', 'engagement_inclow', 'badges_inclow', 'engagement_incmiddle', 'badges_incmiddle', 'break_engagement', 'break_badges', 'break_engagement_inchigh', 'break_badges_inchigh', 'break_engagement_inclow', 'break_badges_inclow', 'break_engagement_incmiddle', 'break_badges_incmiddle', 'emp_combined', 'emp_combined_inclow', 'emp_combined_incmiddle', 'emp_combined_inchigh', 'emp_combined_ss40', 'emp_combined_ss60', 'emp_combined_ss65', 'emp_combined_ss70', 'statename', 'stateabbrev', 'xwalk', 'open_table_seatings', 'pca_0', 'pca_1', 'pca_2', 'pca_3', 'pca_4']
# open_table_seatings          0.659417
# spend_acf                    0.794129
# spend_aer                    0.747166
# spend_all                    0.550774
# spend_apg                    0.507121
# spend_grf                   -0.113231
# spend_hcs                    0.457153
# spend_tws                    0.821747
# spend_all_inchigh            0.487232
# spend_all_inclow             0.337916
# spend_all_incmiddle          0.485851
# spend_retail_w_grocery       0.098264
# spend_retail_no_grocery      0.162231
# gps_retail_and_recreation    0.851155
# gps_grocery_and_pharmacy     0.638303
# gps_transit_stations         0.743776
# gps_workplaces               0.863283
# gps_residential             -0.881178
# gps_away_from_home           0.876011
# merchants_all                0.922952
# merchants_inchigh            0.830753
# merchants_inclow             0.794355
# merchants_incmiddle          0.894531
# merchants_ss40               0.837772
# merchants_ss60               0.565087
# merchants_ss65               0.775740
# merchants_ss70               0.816605
# revenue_all                  0.922281
# revenue_inchigh              0.793955
# revenue_inclow               0.756447
# revenue_incmiddle            0.878114
# revenue_ss40                 0.699445
# revenue_ss60                 0.483936
# revenue_ss65                 0.796589
# revenue_ss70                 0.903513
# emp_combined                 0.711260
# emp_combined_inclow          0.763635
# emp_combined_incmiddle       0.703541
# emp_combined_inchigh         0.557287
# emp_combined_ss40            0.649891
# emp_combined_ss60            0.399850
# emp_combined_ss65            0.698598
# emp_combined_ss70            0.813022
# Name: pca_0, dtype: float64
# open_table_seatings          0.276939
# spend_acf                    0.451175
# spend_aer                    0.078626
# spend_all                    0.753124
# spend_apg                    0.712226
# spend_grf                    0.231471
# spend_hcs                    0.650285
# spend_tws                    0.236907
# spend_all_inchigh            0.636410
# spend_all_inclow             0.681722
# spend_all_incmiddle          0.773267
# spend_retail_w_grocery       0.774060
# spend_retail_no_grocery      0.818720
# gps_retail_and_recreation    0.000174
# gps_grocery_and_pharmacy    -0.293660
# gps_transit_stations        -0.190854
# gps_workplaces               0.071059
# gps_residential             -0.066749
# gps_away_from_home           0.066831
# merchants_all               -0.206381
# merchants_inchigh           -0.187433
# merchants_inclow            -0.230397
# merchants_incmiddle         -0.224610
# merchants_ss40              -0.191280
# merchants_ss60              -0.311414
# merchants_ss65              -0.073263
# merchants_ss70              -0.392985
# revenue_all                 -0.200784
# revenue_inchigh             -0.246669
# revenue_inclow              -0.172938
# revenue_incmiddle           -0.202098
# revenue_ss40                -0.225647
# revenue_ss60                -0.137735
# revenue_ss65                 0.101307
# revenue_ss70                -0.260014
# emp_combined                -0.011722
# emp_combined_inclow         -0.089387
# emp_combined_incmiddle       0.003335
# emp_combined_inchigh         0.341537
# emp_combined_ss40            0.043050
# emp_combined_ss60           -0.039356
# emp_combined_ss65            0.006460
# emp_combined_ss70            0.082567
# Name: pca_1, dtype: float64

# %%
import matplotlib
COLOR = 'white'
matplotlib.rcParams['text.color'] = COLOR
matplotlib.rcParams['axes.labelcolor'] = COLOR
matplotlib.rcParams['xtick.color'] = COLOR
matplotlib.rcParams['ytick.color'] = COLOR
fig = plt.figure(figsize=(8,5))
fig.patch.set_facecolor('#2c2c2c')
final_dat_pca.loc[~final_dat_pca['statefips'].isin([11])].groupby(['Date', 'statename'])['pca_0'].mean().unstack().plot(ax=plt.gca(), cmap='plasma')
plt.gca().get_legend().remove()
plt.gca().patch.set_facecolor('#2c2c2c')

plt.gca().spines['bottom'].set_color(COLOR)
plt.gca().spines['top'].set_color(COLOR) 
plt.gca().spines['right'].set_color(COLOR)
plt.gca().spines['left'].set_color(COLOR)

# %%
### READY FOR FINAL PLOT @SHERIDAN

pca_0_min = final_dat_pca['pca_0'].min()
pca_0_max = final_dat_pca['pca_0'].max()
max_adj = final_dat_pca.loc[final_dat_pca['Date'] <= '02/15/2020', 'pca_0'].mean()
print(final_dat_pca.loc[final_dat_pca['Date'] <= '02/15/2020', 'pca_0'].describe())
final_dat_pca['shadow_index_raw'] = (pca_0_max - final_dat_pca['pca_0'])/(pca_0_max - pca_0_min) * 100
final_dat_pca['shadow_index_normalized'] = final_dat_pca['pca_0'].apply(lambda x: (max_adj - min(x, max_adj))/(max_adj - pca_0_min) * 100)

# fig,ax = plt.subplots(figsize=(10, 15))
# sns.heatmap(final_dat_pca.groupby(['statename', 'Date'])['shadow_index_raw'].mean().unstack(), 
#             cmap='coolwarm', ax=ax)
fig,ax = plt.subplots(figsize=(10, 15))
sns.heatmap(final_dat_pca.groupby(['statename', 'Date'])['shadow_index_normalized'].mean().unstack(), 
            cmap='coolwarm', ax=ax)
# Out:
# count    765.000000
# mean       1.355719
# std        0.199242
# min        0.873038
# 25%        1.233199
# 50%        1.318949
# 75%        1.448243
# max        2.560425
# Name: pca_0, dtype: float64

# %%
final_dat_pca.to_csv(dir + 'US_States/cleaned_data/mobility_pca_data_clean.csv')
final_dat_pca[['statefips', 'statename', 'Date', 'shadow_index_normalized']].to_csv(dir + 'US_States/cleaned_data/mobility_pca_only.csv')
